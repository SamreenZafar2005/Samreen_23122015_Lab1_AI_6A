# %% [markdown]
# <a href="https://colab.research.google.com/github/SamreenZafar2005/Samreen_23122015_Lab1_AI_6A/blob/main/Samreen_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
from google.colab import userdata

# Retrieve API Key from Colab Secrets
api_key = userdata.get("GEMINI_API_KEY")

# Initialize Client
client = genai.Client(api_key=api_key)

print("Gemini Chatbot (type 'exit' to quit)\n")
while True:
    user_input = input("You: ")

    # Exit condition
    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye 👋")
        break

    # Send input using the latest model
    response = client.models.generate_content(
        model="gemini-3.6-flash",
        contents=user_input,
    )

    # Print response
    print("Chatbot:", response.text)
# Out:
# Gemini Chatbot (type 'exit' to quit)
#
# Chatbot: Hello! How can I help you today?
# You: EXPLAIN AI
# Chatbot: **Artificial Intelligence (AI)** is a branch of computer science dedicated to creating systems capable of performing tasks that would typically require human intelligence.
#
# These tasks include things like **learning, reasoning, problem-solving, understanding language, and recognizing patterns.**
#
# Here is a breakdown of how AI works, its different types, and how it impacts our world.
#
# ---
#
# ### 1. How Does AI Work?
#
# Traditional computer programs follow strict, step-by-step instructions (if X happens, do Y). **AI is different because it learns from data.**
#
# Instead of being explicitly programmed for every scenario, an AI system is given massive amounts of data and learns to find patterns on its own.
#
# Think of it like teaching a child to recognize a dog:
# ...
